# %% [markdown]
# # This is a test notebook

# %%
print("hello world")
# Out:
# hello world

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x=np.linspace(1,10,20)
plt.plot(x,np.sin(x))
plt.show()
